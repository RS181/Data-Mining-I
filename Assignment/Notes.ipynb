# %% [markdown]
# # Notas sobre assigment

# %% [markdown]
# 1. Hints para UCMF **preprocessing**:
#     * Remover linhas com <= 2 anos
#
#     * Verificar IMC * (P,A)
#
#     * Verificar range de age
#
#         * Verificar relação entre
#
#         * age * weigth
#
#         * age * height
#
#         * weight * height
#
# * Verificar valores de referência para (detetar valores impossíveis, é precisso saber o que é um outlier e o que é um valor impossivel)
#
#     * IMC
#
#     * SBP
#
#     * DBP
#
#
# 2. Professora recomendou treinar com o iris dataset todas as fases (preprocesing, etc…) porque o dataset é mais simples de perceber e depois devemos passar o para o dataset mais complexo
# 3. Verificar que o tipo de variavel que esta no dataset bate certo com aquele que importamos no python (em certas ferramentas, pode levar (por e.g.) a que variaveis continuas passam a ser inteiras)
# 4. Professora recomendou fazer o relatorio em que estamos a tentar explicar a uma pessoa o que fizemos

# %% [markdown]
# * Para cada objeto (pessoa) vemos a respetiva idade e vemos o minimo valor e maximo valor de SBP e DBP (neste caso a professora recomendou dar uma folga, no exemplo abaixo invez de SBP a 80 por 70 como minimo e maximo 120 invez de 114).
#     * ```Se um objeto não entrar nesse range, devemos remover-lo```
#     * Basicamente o que estamos a fazer, é verificar se as medições que estão lá feitas estão corretas e são válidas
# * Nota: a professora sugeriu  por em algum lado este valores (max-min e respetiva idade e fazer a verificação)

# %% [markdown]
# ![alt text](image.PNG)

# %% [markdown]
# * Ter cuidado nas unidades (No imc acho que usa metros para altura, e altura esta descrita em cm, e ter cuidado com o peso).

# %% [markdown]
# * Features Motivo, pode levar a bias (precissamos de saber se alguma váriavel vai prever a target feature). Nós não queremos isso, queremos um modelo que pege noutra váriaveis (que não permitem prever diretamente a target feature) e tentar com eles prever
#
# * Remover ids únicos também (a menos que os ids tenham informação escondida, e.g. número mecanográfico dá informação sobre o curso que nós estamos por exemplo, e podemos usar essa parte)
