# %% [markdown]
# # **Foundations of Data Science 2025/2026**
# Department of Computer Science, Faculty of Sciences, University of Porto
#
# **Practical #1**
#
# In this class we will get acquainted with some tools you can use in this discipline during the semester. The first of these is `jupyter`. Jupyter helps producing documented code and can be used as a notebook, a lab or in a combination with google services through the **google colab.** The second tool is the programming language. In this discipline we will be using mostly `python`. `Jupyter` can support `python` (among other languages, including `R`).

# %% [markdown]
# Let's start with Pyhthon Pandas (you practiced with pandas last week) by reading a csv (comma-separated-value) file.
#
# Pandas name derives from "panel data", a term very much used in econometrics (you can find full documentation for pandas [here](https://pandas.pydata.org/docs/) and a good introductory tutorial [here](https://towardsdatascience.com/a-quick-introduction-to-the-pandas-python-library-f1b678f34673)).
#
# Our data file is from [kaggle](https://www.kaggle.com) and can be found [here](https://www.kaggle.com/emilianito/saheart). You have to download it to your disk and either upload it to the remote colab machine created to run your code or upload it to your google drive. If you upload it to the remote machine disk, whenever you reconnect to the remote machine, you will need to upload the file again. If you upload it to google drive, it will remain accessible. In order to access the file from the google drive you need to mount it (click on the file icon on the left panel and on the drive icon). Once the file is uploaded, you can see it on the left panel after you click in the file icon. In order to know the file path and copy it to your code (and use it with `read_csv`), hover the mouse on the filename and use the left mouse button. A menu will appear with "Copy path".

# %%
# Enable autocomplete
# %config IPCompleter.greedy=True

# %%
import pandas as pd
mydata = pd.read_csv('DataSets/SAheart.csv')

# %%
# I used Jupiter notebook so no need for this 
#from google.colab import drive
#drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Let's inspect the contents of this file...

# %%
pd.set_option("display.max_rows",None)

# %%
mydata.head()
# Out:
#    sbp  tobacco   ldl  adiposity  famhist  typea  obesity  alcohol  age chd
# 0  160    12.00  5.73      23.11  Present     49    25.30    97.20   52  Si
# 1  144     0.01  4.41      28.61   Absent     55    28.87     2.06   63  Si
# 2  118     0.08  3.48      32.28  Present     52    29.14     3.81   46  No
# 3  170     7.50  6.41      38.03  Present     51    31.99    24.26   58  Si
# 4  134    13.60  3.50      27.78  Present     60    25.99    57.34   49  Si

# %%
mydata.describe(include="all")
# Out:
#                sbp     tobacco         ldl   adiposity famhist       typea  \
# count   462.000000  462.000000  462.000000  462.000000     462  462.000000
# unique         NaN         NaN         NaN         NaN       2         NaN
# top            NaN         NaN         NaN         NaN  Absent         NaN
# freq           NaN         NaN         NaN         NaN     270         NaN
# mean    138.326840    3.635649    4.740325   25.406732     NaN   53.103896
# std      20.496317    4.593024    2.070909    7.780699     NaN    9.817534
# min     101.000000    0.000000    0.980000    6.740000     NaN   13.000000
# 25%     124.000000    0.052500    3.282500   19.775000     NaN   47.000000
# 50%     134.000000    2.000000    4.340000   26.115000     NaN   53.000000
# 75%     148.000000    5.500000    5.790000   31.227500     NaN   60.000000
# max     218.000000   31.200000   15.330000   42.490000     NaN   78.000000
#
#            obesity     alcohol         age  chd
# ...

# %% [markdown]
# `describe()` is the method that gives a descriptive statistics of the data. Notice the different types of variables that we have in this dataset (for example, `famhist` is **categorical**, `age` is **integer** and `ldl` is **floating point** (continuous).
#
# The dataset contains a retrospective sample of males in a heart-disease high-risk region of the Western Cape, South Africa. There are roughly two controls per case of Coronary Heart Disease (CHD). Many of the CHD positive men have undergone blood pressure reduction treatment and other programs to reduce their risk factors after their CHD event. In some cases the measurements were made after these treatments. These data are taken from a larger dataset, described in Rousseauw et al, 1983, South African Medical Journal.
#
# The class label indicates if the person has a coronary heart disease: negative (`No`) or positive (`Si`).
#
# Attributes description:
# - sbp: systolic blood pressure
# - tobacco: cumulative tobacco (kg)
# - ldl: low density lipoprotein cholesterol
# - adiposity
# - famhist: family history of heart disease (Present, Absent)
# - typea: type-A behavior
# - obesity
# - alcohol: current alcohol consumption
# - age: age at onset

# %% [markdown]
# Make a copy of this notebook and try to explain the output of `describe()`. Keep it for your own records.
#
# Now, let's explore a little bit more.

# %%
import matplotlib.pyplot as plt
plt.plot(mydata['sbp'])
plt.plot(sorted(mydata['sbp']))

# %%
mydata['sbp'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
mydata['sbp'].plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
plt.plot(mydata['ldl'])
plt.plot(sorted(mydata['ldl']))

# %%
mydata['ldl'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
mydata['ldl'].plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
no_cat_mydata = mydata.drop(['famhist','chd'],axis='columns')
normalized_mydata=(no_cat_mydata - no_cat_mydata.min())/(no_cat_mydata.max() - no_cat_mydata.min())
normalized_mydata.head()
# Out:
#         sbp   tobacco       ldl  adiposity     typea   obesity   alcohol  \
# 0  0.504274  0.384615  0.331010   0.457902  0.553846  0.332497  0.660371
# 1  0.367521  0.000321  0.239024   0.611748  0.646154  0.444479  0.013996
# 2  0.145299  0.002564  0.174216   0.714406  0.600000  0.452949  0.025885
# 3  0.589744  0.240385  0.378397   0.875245  0.584615  0.542346  0.164821
# 4  0.282051  0.435897  0.175610   0.588531  0.723077  0.354141  0.389565
#
#         age
# 0  0.755102
# 1  0.979592
# 2  0.632653
# 3  0.877551
# 4  0.693878

# %%
normalized_mydata.plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
print(mydata.mode())
# Out:
#      sbp  tobacco   ldl  adiposity famhist  typea  obesity  alcohol   age  chd
# 0  134.0      0.0  3.57      21.10  Absent   52.0    24.86      0.0  16.0   No
# 1  136.0      NaN  3.95      27.55     NaN    NaN    26.09      NaN   NaN  NaN
# 2    NaN      NaN  4.37      29.30     NaN    NaN      NaN      NaN   NaN  NaN
# 3    NaN      NaN   NaN      30.79     NaN    NaN      NaN      NaN   NaN  NaN

# %%
# to print without dots
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
print(mydata.mode())
# Out:
#      sbp  tobacco   ldl  adiposity famhist  typea  obesity  alcohol   age  chd
# 0  134.0      0.0  3.57      21.10  Absent   52.0    24.86      0.0  16.0   No
# 1  136.0      NaN  3.95      27.55     NaN    NaN    26.09      NaN   NaN  NaN
# 2    NaN      NaN  4.37      29.30     NaN    NaN      NaN      NaN   NaN  NaN
# 3    NaN      NaN   NaN      30.79     NaN    NaN      NaN      NaN   NaN  NaN

# %% [markdown]
# If you need help with methods, functions or other resources in python, you can use the help command, as illustrated below.

# %%
help(pd.DataFrame.drop)
# Out:
# Help on function drop in module pandas.core.frame:
#
# drop(
#     self,
#     labels: 'IndexLabel | None' = None,
#     *,
#     axis: 'Axis' = 0,
#     index: 'IndexLabel | None' = None,
#     columns: 'IndexLabel | None' = None,
#     level: 'Level | None' = None,
#     inplace: 'bool' = False,
#     errors: 'IgnoreRaise' = 'raise'
# ) -> 'DataFrame | None'
#     Drop specified labels from rows or columns.
#
#     Remove rows or columns by specifying label names and corresponding
#     axis, or by directly specifying index or column names. When using a
#     multi-index, labels on different levels can be removed by specifying
#     the level. See the :ref:`user guide <advanced.shown_levels>`
#     for more information about the now unused levels.
#
#     Parameters
#     ----------
#     labels : single label or list-like
#         Index or column labels to drop. A tuple will be used as a single
#         label and not treated as a list-like.
# ...

# %% [markdown]
# ---
#
# # **Exercises**
# (based on https://pynative.com/python-pandas-exercise/)
#
# (other good source for exercising data science tasks in python: https://www.machinelearningplus.com/python/101-pandas-exercises-python/)
#
#
# 1.   From the data presented in the previous section, print the first and the last five rows.
#
# 2.   What are the types of each variable?
#
# 2.   Replace all `age` values with NaN.
#
# 3.   Print the highest `sbp` value.
#
# 4.   Print all rows with `famhist` equals to "Absent".
#
# 5.   Count total patients with `famhist` equals to "Present".
#
# 6.   Count all patients with `ldl` value above 5.
#
# 8.   Find the average value of `age`.
#
# 9.   Sort all patients by increasing order of `age`.
#
# 7.   Is there a relation between high `sbp` and `alcohol` intake?

# %% [markdown]
# 1.  From the data presented in the previous section, print the first and the last five rows.

# %%
mydata.head(5)
# Out:
#    sbp  tobacco   ldl  adiposity  famhist  typea  obesity  alcohol  age chd
# 0  160    12.00  5.73      23.11  Present     49    25.30    97.20   52  Si
# 1  144     0.01  4.41      28.61   Absent     55    28.87     2.06   63  Si
# 2  118     0.08  3.48      32.28  Present     52    29.14     3.81   46  No
# 3  170     7.50  6.41      38.03  Present     51    31.99    24.26   58  Si
# 4  134    13.60  3.50      27.78  Present     60    25.99    57.34   49  Si

# %%
mydata.tail(5)

# %% [markdown]
# 2. What are the types of each variable?

# %%
mydata.dtypes
# Out:
# sbp            int64
# tobacco      float64
# ldl          float64
# adiposity    float64
# famhist       object
# typea          int64
# obesity      float64
# alcohol      float64
# age            int64
# chd           object
# dtype: object

# %% [markdown]
# 3. Replace all age values with NaN.

# %%
import numpy as np
mydata['age'] = np.nan
mydata.head()
# Out:
#    sbp  tobacco   ldl  adiposity  famhist  typea  obesity  alcohol  age chd
# 0  160    12.00  5.73      23.11  Present     49    25.30    97.20  NaN  Si
# 1  144     0.01  4.41      28.61   Absent     55    28.87     2.06  NaN  Si
# 2  118     0.08  3.48      32.28  Present     52    29.14     3.81  NaN  No
# 3  170     7.50  6.41      38.03  Present     51    31.99    24.26  NaN  Si
# 4  134    13.60  3.50      27.78  Present     60    25.99    57.34  NaN  Si

# %% [markdown]
# 4. Print the highest sbp value.

# %%
mydata['sbp'].max()
# Out:
# np.int64(218)

# %% [markdown]
# 5. Print all rows with famhist equals to "Absent".

# %%
mydata.loc[mydata['famhist']=='Absent'].head()
# Out:
#     sbp  tobacco   ldl  adiposity famhist  typea  obesity  alcohol  age chd
# 1   144     0.01  4.41      28.61  Absent     55    28.87     2.06  NaN  Si
# 6   142     4.05  3.38      16.20  Absent     59    20.81     2.62  NaN  No
# 10  206     6.00  2.95      32.27  Absent     72    26.81    56.06  NaN  Si
# 12  118     0.00  1.88      10.05  Absent     59    21.57     0.00  NaN  No
# 13  132     0.00  1.87      17.21  Absent     49    23.63     0.97  NaN  No

# %% [markdown]
# 6. Count total patients with famhist equals to "Present".

# %%
len(mydata.loc[mydata['famhist']=='Present'])
# Out:
# 192

# %% [markdown]
# 7. Count all patients with ldl value above 5.

# %%
len(mydata.loc[mydata['ldl']>5])
# Out:
# 170

# %% [markdown]
# 8. Find the average value of age.

# %%
# Reload csv to get age value
mydata = pd.read_csv('SAheart.csv')
mydata['age'].mean()
# Out:
# np.float64(42.816017316017316)

# %% [markdown]
# 9. Sort all patients by increasing order of `age`.

# %%
mydata.sort_values('age').head(20)
# Out:
#      sbp  tobacco   ldl  adiposity  famhist  typea  obesity  alcohol  age chd
# 42   120     0.00  1.07      16.02   Absent     47    22.15     0.00   15  No
# 70   118     0.00  3.67      12.13   Absent     51    19.15     0.60   15  No
# 13   132     0.00  1.87      17.21   Absent     49    23.63     0.97   15  No
# 110  114     0.00  8.01      21.64   Absent     66    25.51     2.49   16  No
# 162  138     0.00  2.68      17.04   Absent     42    22.16     0.00   16  No
# 279  118     0.12  3.26      12.26   Absent     55    22.65     0.00   16  No
# 278  114     0.00  2.63       9.69   Absent     45    17.89     0.00   16  No
# 441  120     0.00  3.98      13.19  Present     47    21.89     0.00   16  No
# 48   114     0.00  1.94      11.02   Absent     54    20.17    38.98   16  No
# 288  123     0.05  4.61      13.69   Absent     51    23.23     2.78   16  No
# 409  120     0.00  3.10      26.97   Absent     41    24.80     0.00   16  No
# ...

# %% [markdown]
# 10. Is there a relation between high `sbp` and `alcohol` intake?

# %%
# DUVIDA NESTE
mydata.loc[:,['sbp','alcohol']].corr(numeric_only=True)
# Out:
#               sbp   alcohol
# sbp      1.000000  0.140096
# alcohol  0.140096  1.000000

# %%
import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")
mydata[['sbp','alcohol']].plot()
# Out:
# <Axes: >

# %% [markdown]
# #**The Red Wine Data Set**
#
# The Red Wine dataset is a machine learning classic with Portuguese origin. The original dataset was published by Paulo Cortez from U. Minho. You can download it [here](https://www.kaggle.com/lctc12/dataset-wine). Then you can play with it:
#
# 1. Load the data as a data frame.
# 2. What is the type of each variable?
# 2. Get the summary data: average, modes and standard deviation for each column.
# 3. Plot the density estimation of the different columns before and after normalization.
# 4. Plot a bar chart with the distribution of the values of `quality`.
# 4. Plot selected pairs of variables against each other.
# 5. Explore the data as you wish.

# %% [markdown]
# 1. Load the data as a data frame.

# %%
df = pd.read_csv("DataSets/wine.csv")
df.head()
# Out:
#    Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0     1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1     1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2     1    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3     1    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4     1    13.24        2.59  2.87  21.0  118     2.80        2.69
#
#    Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                  0.28     2.29       5.64  1.04  3.92     1065
# 1                  0.26     1.28       4.38  1.05  3.40     1050
# 2                  0.30     2.81       5.68  1.03  3.17     1185
# 3                  0.24     2.18       7.80  0.86  3.45     1480
# 4                  0.39     1.82       4.32  1.04  2.93      735

# %% [markdown]
# 2. What is the type of each variable?

# %%
df.dtypes
# Out:
# Wine                      int64
# Alcohol                 float64
# Malic.acid              float64
# Ash                     float64
# Acl                     float64
# Mg                        int64
# Phenols                 float64
# Flavanoids              float64
# Nonflavanoid.phenols    float64
# Proanth                 float64
# Color.int               float64
# Hue                     float64
# OD                      float64
# Proline                   int64
# dtype: object

# %% [markdown]
# 3. Get the summary data: average, modes and standard deviation for each column.

# %%
df.describe()
# Out:
#              Wine     Alcohol  Malic.acid         Ash         Acl          Mg  \
# count  178.000000  178.000000  178.000000  178.000000  178.000000  178.000000
# mean     1.938202   13.000618    2.336348    2.366517   19.494944   99.741573
# std      0.775035    0.811827    1.117146    0.274344    3.339564   14.282484
# min      1.000000   11.030000    0.740000    1.360000   10.600000   70.000000
# 25%      1.000000   12.362500    1.602500    2.210000   17.200000   88.000000
# 50%      2.000000   13.050000    1.865000    2.360000   19.500000   98.000000
# 75%      3.000000   13.677500    3.082500    2.557500   21.500000  107.000000
# max      3.000000   14.830000    5.800000    3.230000   30.000000  162.000000
#
#           Phenols  Flavanoids  Nonflavanoid.phenols     Proanth   Color.int  \
# count  178.000000  178.000000            178.000000  178.000000  178.000000
# mean     2.295112    2.029270              0.361854    1.590899    5.058090
# ...

# %% [markdown]
# 4. Plot the density estimation of the different columns before and after normalization.

# %%
# Before normalization
df.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
# Fiz normalização com a técnica "min-max feature scaling" 
# TODO CONFIRMAR 
scaled = df.copy()
for column in scaled.columns:
    scaled[column] = (scaled[column] - scaled[column].min()) / (scaled[column].max() - scaled[column].min())
scaled.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# 5. Plot a bar chart with the distribution of the values of quality.

# %%
#df['quality'].plot(kind='bar')
# DÚVIDA: Não existe nenhuma coluna 'quality'

# %% [markdown]
# 6.  Plot selected pairs of variables against each other.

# %%
df[['Mg','Acl']].plot()
# Out:
# <Axes: >
